# %% [markdown]
# <a href="https://colab.research.google.com/github/mfernandes10/MetNumUN2023I/blob/main/Lab3/mfernandes_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("This is Lab 3")
# Out:
# This is Lab 3

# %% [markdown]
# **Python 101 for Data Science**

# %% [markdown]
# ![Certi 1 python.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **Data Analysis with Python**

# %% [markdown]
# ![certi 2 python.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **Data Visualization with Python**

# %% [markdown]
# ![certi 3 python.JPG](data:image/jpeg;base64,...)
